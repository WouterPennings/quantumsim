# %%
import networkx as nx
import matplotlib.pyplot as plt

import max_cut

# %%
# G = nx.connected_caveman_graph(l=2, k=3)  

# Define nodes and edges
G = nx.house_x_graph()

max_cut_partition = max_cut.maxcut_bruteforce(G.nodes, G.edges)
print(max_cut_partition)
max_cut.show_graph_partition(G.nodes, G.edges, max_cut_partition[0])
# Out:
# Partition {0: 0, 1: 0, 2: 0, 3: 0, 4: 1} has cut size 2
# Partition {0: 0, 1: 0, 2: 0, 3: 1, 4: 0} has cut size 4
# Partition {0: 0, 1: 0, 2: 0, 3: 1, 4: 1} has cut size 4
# Partition {0: 0, 1: 0, 2: 1, 3: 0, 4: 0} has cut size 4
# Partition {0: 0, 1: 0, 2: 1, 3: 0, 4: 1} has cut size 4
# Partition {0: 0, 1: 0, 2: 1, 3: 1, 4: 0} has cut size 6
# Partition {0: 0, 1: 0, 2: 1, 3: 1, 4: 1} has cut size 4
# Partition {0: 0, 1: 1, 2: 0, 3: 0, 4: 0} has cut size 3
# Partition {0: 0, 1: 1, 2: 0, 3: 0, 4: 1} has cut size 5
# Partition {0: 0, 1: 1, 2: 0, 3: 1, 4: 0} has cut size 5
# Partition {0: 0, 1: 1, 2: 0, 3: 1, 4: 1} has cut size 5
# Partition {0: 0, 1: 1, 2: 1, 3: 0, 4: 0} has cut size 5
# Partition {0: 0, 1: 1, 2: 1, 3: 0, 4: 1} has cut size 5
# Partition {0: 0, 1: 1, 2: 1, 3: 1, 4: 0} has cut size 5
# Partition {0: 0, 1: 1, 2: 1, 3: 1, 4: 1} has cut size 3
# Partition {0: 1, 1: 0, 2: 0, 3: 0, 4: 0} has cut size 3
# Partition {0: 1, 1: 0, 2: 0, 3: 0, 4: 1} has cut size 5
# ...
