# %% [markdown]
# # `quantumsim.py` vs `quantumsim_performante.py`
#
# Author: Wouter Pennings<br>
# Date: May, 2025
#
# The regular (Nico's) version of QuantumSim compared to the more performance (Wouter's) version of QuantumSim. This comparison focusses on a variety of different things, such as performance and validity. The regular version is the standard to which the performance version is compared to.

# %% [markdown]
# # Validity Testing simulators
#
# The tests are copied from the `QuantumSimNoise.ipynb` notebook

# %% [markdown]
# ## quantumsim validity

# %%
from quantumsim import *

# %% [markdown]
# ### Test 1

# %%
n = 100 # Number of gate operations
circuit = NoisyCircuit(1)
for i in range(n):
    circuit.pauli_x(0)
    circuit.add_noisy_operation_coherent_x(3, 0)
circuit.add_noisy_operation_state_prep(0.08, 0)
circuit.add_noisy_operation_incoherent(0.007, 0.008, 0.009, 0)
circuit.add_noisy_operation_readout(0.02, 0.05, 0)

result = QuantumUtil.measure_circuit(circuit, nr_measurements=1000)
QuantumUtil.histogram_of_classical_states(result)

# %% [markdown]
# ### Test 2

# %%
n = 100
circuit = NoisyCircuit(2)
for i in range(n):
    circuit.pauli_x(0)
    circuit.add_noisy_operation_coherent_x(3, 0)
    circuit.pauli_y(1)
    circuit.add_noisy_operation_coherent_y(4, 1)
circuit.add_noisy_operation_state_prep(0.08, 0)
circuit.add_noisy_operation_state_prep(0.07, 1)
circuit.add_noisy_operation_incoherent(0.007, 0.008, 0.009, 0)
circuit.add_noisy_operation_incoherent(0.003, 0.004, 0.005, 1)
circuit.add_noisy_operation_readout(0.02, 0.05, 0)
circuit.add_noisy_operation_readout(0.04, 0.03, 0)

result = QuantumUtil.measure_circuit(circuit, nr_measurements=1000)
QuantumUtil.histogram_of_classical_states(result)

# %% [markdown]
# ### Test 3

# %%
n = 100
circuit = NoisyCircuit(2)
for i in range(n):
    circuit.pauli_x(0)
    circuit.add_noisy_operation_coherent_x(3, 0)
    circuit.cnot(0,1)

result = QuantumUtil.measure_circuit(circuit, nr_measurements=1000)
QuantumUtil.histogram_of_classical_states(result)

# %% [markdown]
# ## quantumsim_performante validity

# %%
from quantumsim_performante.quantumsim_performante import *
import quantumsim_performante.quantumutil as QuantumUtil

# %% [markdown]
# ### Test 1

# %%
n = 100 # Number of gate operations
circuit = NoisyCircuit(1)
for i in range(n):
    circuit.pauli_x(0)
    circuit.add_noisy_operation_coherent_x(3, 0)
circuit.add_noisy_operation_state_prep(0.08, 0)
circuit.add_noisy_operation_incoherent(0.007, 0.008, 0.009, 0)
circuit.add_noisy_operation_readout(0.02, 0.05, 0)

result = QuantumUtil.measure_circuit(circuit, nr_measurements=1000)
QuantumUtil.histogram_of_classical_states(result)

# %% [markdown]
# ### Test 2

# %%
n = 100 # Number of gate operations
circuit = NoisyCircuit(2)
for i in range(n):
    circuit.pauli_x(0)
    circuit.add_noisy_operation_coherent_x(3, 0)
    circuit.pauli_y(1)
    circuit.add_noisy_operation_coherent_y(4, 1)
circuit.add_noisy_operation_state_prep(0.08, 0)
circuit.add_noisy_operation_state_prep(0.07, 1)
circuit.add_noisy_operation_incoherent(0.007, 0.008, 0.009, 0)
circuit.add_noisy_operation_incoherent(0.003, 0.004, 0.005, 1)
circuit.add_noisy_operation_readout(0.02, 0.05, 0)
circuit.add_noisy_operation_readout(0.04, 0.03, 0)

result = QuantumUtil.measure_circuit(circuit, nr_measurements=1000)
QuantumUtil.histogram_of_classical_states(result)

# %% [markdown]
# ### Test 3

# %%
n = 100 # Number of gate operations
circuit = NoisyCircuit(2)
for i in range(n):
    circuit.pauli_x(0)
    circuit.add_noisy_operation_coherent_x(3, 0)
    circuit.cnot(0,1)

result = QuantumUtil.measure_circuit(circuit, nr_measurements=1000)
QuantumUtil.histogram_of_classical_states(result)

# %% [markdown]
# ## Conclusion validity
#
# `quantumsim_performante.py` is identical `quantumsim.py` as all three test have the same output

# %% [markdown]
# # Rough benchmarks

# %%
from time import perf_counter

# Qubits for testing
N = 10

# %% [markdown]
# ## Quantunsim

# %%
from quantumsim import *

n = 100
circuit = NoisyCircuit(N)

t1 = perf_counter()

for i in range(n):
    circuit.pauli_x(0)
    circuit.add_noisy_operation_coherent_x(3, 0)
    circuit.pauli_y(1)
    circuit.add_noisy_operation_coherent_y(4, 1)
circuit.add_noisy_operation_state_prep(0.08, 0)
circuit.add_noisy_operation_state_prep(0.07, 1)
circuit.add_noisy_operation_incoherent(0.007, 0.008, 0.009, 0)
circuit.add_noisy_operation_incoherent(0.003, 0.004, 0.005, 1)
circuit.add_noisy_operation_readout(0.02, 0.05, 0)
circuit.add_noisy_operation_readout(0.04, 0.03, 0)

result = QuantumUtil.measure_circuit(circuit, nr_measurements=1000)

t2 = perf_counter()
print(f"Total exection time: {t2 -t1}")

QuantumUtil.histogram_of_classical_states(result)

# %% [markdown]
# ## QuantumSim performante

# %%
from quantumsim_performante.quantumsim_performante import *
import quantumsim_performante.quantumutil as QuantumUtil

n = 100
circuit = NoisyCircuit(N)

t1 = perf_counter()

for i in range(n):
    circuit.pauli_x(0)
    circuit.add_noisy_operation_coherent_x(3, 0)
    circuit.pauli_y(1)
    circuit.add_noisy_operation_coherent_y(4, 1)
circuit.add_noisy_operation_state_prep(0.08, 0)
circuit.add_noisy_operation_state_prep(0.07, 1)
circuit.add_noisy_operation_incoherent(0.007, 0.008, 0.009, 0)
circuit.add_noisy_operation_incoherent(0.003, 0.004, 0.005, 1)
circuit.add_noisy_operation_readout(0.02, 0.05, 0)
circuit.add_noisy_operation_readout(0.04, 0.03, 0)

result = QuantumUtil.measure_circuit(circuit, nr_measurements=1000)

t2 = perf_counter()
print(f"Total exection time: {t2 - t1}")

QuantumUtil.histogram_of_classical_states(result)

# %% [markdown]
# # Sparsity of matrices for noisy simulations

# %% [markdown]
# ## Sparsity of noisy operation matrices

# %%
from quantumsim_performante.quantumsim_performante import *

N = 10

print(f"Elements in operation matrix: {2**N*2**N}")

circuit = NoisyCircuit(N)
circuit.noisy_cnot(0, 1)
circuit.cnot(0, 1)
print("CNOT")
print(f"  > Noisy  NNZ: {circuit.operations[0].nnz}")
print(f"  > Normal NNZ: {circuit.operations[1].nnz}")

circuit = NoisyCircuit(N)
circuit.noisy_hadamard(0)
circuit.hadamard(0)
print("HADAMARD")
print(f"  > Noisy  NNZ: {circuit.operations[0].nnz}")
print(f"  > Normal NNZ: {circuit.operations[1].nnz}")

circuit = NoisyCircuit(N)
circuit.noisy_pauli_x(0)
circuit.pauli_x(0)
print("PAULI X")
print(f"  > Noisy  NNZ: {circuit.operations[0].nnz}")
print(f"  > Normal NNZ: {circuit.operations[1].nnz}")

circuit = NoisyCircuit(N)
circuit.noisy_phase(10, 0)
circuit.phase(10, 0)
print("PHASE")
print(f"  > Noisy  NNZ: {circuit.operations[0].nnz}")
print(f"  > Normal NNZ: {circuit.operations[1].nnz}")

# %% [markdown]
# Remember, every additional qubits makes the matrices twice as sparse. This can be found in `QuantumSimComputationalImprovements.ipynb`

# %% [markdown]
# ## Sparsity of noise matrices
#
# Talking about these three noise matrices:
#
# ```python
# self.noisy_operations_state_prep: sparse.coo_matrix = []
# self.noisy_operations_incoherent: sparse.coo_matrix = []
# self.noisy_operations_readout: sparse.coo_matrix = []
# ```
#
# These noise matrices are multiplied with the `StateVector` during execution or measurement

# %%
print("Sparsity noise matrices: ")

for N in range(3, 7):
    elements = 2**N*2**N
    print(f"    > Elements in dense noise matrix: {elements}")
    circuit = NoisyCircuit(N)
    circuit.add_noisy_operation_state_prep(0.07, 1)
    circuit.add_noisy_operation_incoherent(0.003, 0.004, 0.005, 1)
    circuit.add_noisy_operation_readout(0.04, 0.03, 0)

    print(f"\t> noisy_operations_state_prep: {circuit.noisy_operations_state_prep[0].nnz/elements * 100}%")
    print(f"\t> noisy_operations_incoherent: {circuit.noisy_operations_incoherent[0].nnz/elements * 100}%")
    print(f"\t> noisy_operations_readout: {circuit.noisy_operations_readout[0].nnz/elements * 100}%\n")

# %% [markdown]
# Just like with the unitary operational matrices, every additional qubits makes the noise matrices twice as sparse.

# %% [markdown]
# ## Noise parameters

# %%
from quantumsim_performante.quantumsim_performante import *

circuit = NoisyCircuit(5)
circuit.parameters
# Out:
# {'T1': [0.00031660780912721775,
#   0.00040556058393406496,
#   0.00024314832711201225,
#   0.00039634790184213647,
#   0.00017464899233685132],
#  'T2': [0.0005387662300407963,
#   0.00020285750076393328,
#   0.00013162106223665532,
#   0.0001783164779575768,
#   0.00013899865262005268],
#  'p': [0.00069944082458343,
#   0.00016373681708611835,
#   0.0003196705914103649,
#   0.0002196360650218448,
#   0.0006700486286950454]}

# %% [markdown]
# # Noisy gate performance

# %%
from time import perf_counter

circuit = NoisyCircuit(5)

t1 = perf_counter()
circuit.noisy_cnot(1, 2)
t2 = perf_counter()
print(f"Time noisy CNOT: {t2-t1}")

t1 = perf_counter()
circuit.cnot(1, 2)
t2 = perf_counter()
print(f"Time CNOT: {t2-t1}")

t1 = perf_counter()
circuit.noisy_pauli_x(1)
t2 = perf_counter()
print(f"Time noisy Pauli X: {t2-t1}")

t1 = perf_counter()
circuit.pauli_x(1)
t2 = perf_counter()
print(f"Time Pauli X: {t2-t1}")

t1 = perf_counter()
circuit.rotate_z(1, 1)
t2 = perf_counter()
print(f"Time Rotate Z: {t2-t1}")


n = 300

circuit = NoisyCircuit(5, use_cache=True)
t1 = perf_counter()
for _ in range(n):
    circuit.noisy_cnot(1, 3)
    circuit.rotate_z(2, 2)
    circuit.noisy_cnot(1, 2)
t2 = perf_counter()
print(f"Time QAOA simplified with caching: {t2-t1}")

circuit = NoisyCircuit(5)
t1 = perf_counter()
for _ in range(n):
    circuit.noisy_cnot(1, 3)
    circuit.rotate_z(2, 2)
    circuit.noisy_cnot(1, 2)
t2 = perf_counter()
print(f"Time QAOA simplified: {t2-t1}")

t1 = perf_counter()
circuit.execute()
t2 = perf_counter()
print(f"Time QAOA simplified executed: {t2-t1}")
# Out:
# Time noisy CNOT: 0.0127714000409469
# Time CNOT: 0.0016971000004559755
# Time noisy Pauli X: 0.0016320000286214054
# Time Pauli X: 0.0006371000199578702
# Time Rotate Z: 0.0006366000161506236
# Time QAOA simplified with caching: 0.027302500035148114
# Time QAOA simplified: 7.606541900022421
# Time QAOA simplified executed: 7.817829800012987

# %% [markdown]
# ## Noise vs noise-less simulations
#
# What part of the computation is spend on actual simulation, what part is spend on noise modeling.
