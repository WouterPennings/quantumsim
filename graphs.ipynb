# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
import networkx as nx
import matplotlib.pyplot as plt

n = 5  # number of nodes
k = 4   # each node connected to k neighbors
p = 0.2 # probability of adding a shortcut

G = nx.newman_watts_strogatz_graph(n, k, p)

nx.draw(G, with_labels=True)
plt.show()

# %%
G = nx.connected_caveman_graph(l=2, k=3)  # 3 cliques of 4 nodes

nx.draw(G, with_labels=True)
plt.show()

# %%
G = nx.house_x_graph()

nx.draw(G, with_labels=True)
plt.show()
