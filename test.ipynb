# %%
import quantumsim_performante.quantumutil as QuantumUtil
from maxcut import show_graph, show_graph_partition, cut_size, compute_partition, compute_average_cut_size, maxcut_QAOA, maxcut_bruteforce
import networkx as nx

# %%
G = nx.watts_strogatz_graph(5, 4, 0.1)
nodes = G.nodes
edges = G.edges

show_graph(G.nodes, G.edges)

# %%
result = maxcut_QAOA(nodes, edges, noisy=False, use_GPU=True, use_cache=True)

average_cut_size = compute_average_cut_size(nodes, edges, result)
partition = compute_partition(nodes, edges, result)
partition_cut_size = cut_size(edges, partition)

print(f"Partition {partition} has cut size {partition_cut_size}")
print(f"Average cut size is {average_cut_size}")
QuantumUtil.histogram_of_classical_states(result)
show_graph_partition(nodes, edges, partition)
# Out:
# Partition {0: 1, 1: 1, 2: 1, 3: 0, 4: 0} has cut size 6
# Average cut size is 5.86597

# %%
result = maxcut_QAOA(nodes, edges, noisy=True, use_cache=True)

average_cut_size = compute_average_cut_size(nodes, edges, result)
partition = compute_partition(nodes, edges, result)
partition_cut_size = cut_size(edges, partition)

print(f"Partition {partition} has cut size {partition_cut_size}")
print(f"Average cut size is {average_cut_size}")
QuantumUtil.histogram_of_classical_states(result)
show_graph_partition(nodes, edges, partition)
# Out:
# Partition {0: 0, 1: 1, 2: 0, 3: 0, 4: 1} has cut size 6
# Average cut size is 5.39876

# %%
G = nx.watts_strogatz_graph(10, 4, 0.1)
nodes = G.nodes
edges = G.edges

show_graph(G.nodes, G.edges)

# %%
result = maxcut_QAOA(nodes, edges, noisy=False, use_GPU=True, use_cache=True)

average_cut_size = compute_average_cut_size(nodes, edges, result)
partition = compute_partition(nodes, edges, result)
partition_cut_size = cut_size(edges, partition)

print(f"Partition {partition} has cut size {partition_cut_size}")
print(f"Average cut size is {average_cut_size}")
QuantumUtil.histogram_of_classical_states(result)
show_graph_partition(nodes, edges, partition)
# Out:
# Partition {0: 0, 1: 1, 2: 0, 3: 1, 4: 0, 5: 1, 6: 0, 7: 1, 8: 0, 9: 1} has cut size 10
# Average cut size is 9.11074

# %%
partitions, maxcut_index = maxcut_bruteforce(nodes, edges)
print(partitions[maxcut_index])

show_graph_partition(nodes, edges, partitions[maxcut_index][0])
# Out:
# ({0: 0, 1: 0, 2: 1, 3: 0, 4: 0, 5: 1, 6: 0, 7: 0, 8: 1, 9: 1}, 14)

# %%
G = nx.watts_strogatz_graph(15, 4, 0.1)
nodes = G.nodes
edges = G.edges

show_graph(G.nodes, G.edges)

# %%
result = maxcut_QAOA(nodes, edges, noisy=False, use_GPU=True, use_cache=True)

average_cut_size = compute_average_cut_size(nodes, edges, result)
partition = compute_partition(nodes, edges, result)
partition_cut_size = cut_size(edges, partition)

print(f"Partition {partition} has cut size {partition_cut_size}")
print(f"Average cut size is {average_cut_size}")
# QuantumUtil.histogram_of_classical_states(result)
show_graph_partition(nodes, edges, partition)
# Out:
# Partition {0: 0, 1: 1, 2: 1, 3: 1, 4: 1, 5: 0, 6: 1, 7: 1, 8: 1, 9: 1, 10: 0, 11: 1, 12: 0, 13: 1, 14: 0} has cut size 14
# Average cut size is 14.94315

# %%
partitions, maxcut_index = maxcut_bruteforce(nodes, edges)
print(partitions[maxcut_index])

show_graph_partition(nodes, edges, partitions[maxcut_index][0])
# Out:
# ({0: 0, 1: 0, 2: 1, 3: 0, 4: 0, 5: 1, 6: 1, 7: 0, 8: 0, 9: 1, 10: 1, 11: 0, 12: 0, 13: 1, 14: 1}, 22)

# %%
G = nx.watts_strogatz_graph(20, 4, 0.1)
nodes = G.nodes
edges = G.edges

show_graph(G.nodes, G.edges)

# %%
result = maxcut_QAOA(nodes, edges, noisy=False, use_GPU=True, use_lazy=True)

average_cut_size = compute_average_cut_size(nodes, edges, result)
partition = compute_partition(nodes, edges, result)
partition_cut_size = cut_size(edges, partition)

print(f"Partition {partition} has cut size {partition_cut_size}")
print(f"Average cut size is {average_cut_size}")
# QuantumUtil.histogram_of_classical_states(result)
show_graph_partition(nodes, edges, partition)

# %%
G = nx.watts_strogatz_graph(25, 4, 0.1)
nodes = G.nodes
edges = G.edges

show_graph(G.nodes, G.edges)

# %%
result = maxcut_QAOA(nodes, edges, noisy=False, use_cache=True, use_lazy=True)

average_cut_size = compute_average_cut_size(nodes, edges, result)
partition = compute_partition(nodes, edges, result)
partition_cut_size = cut_size(edges, partition)

print(f"Partition {partition} has cut size {partition_cut_size}")
print(f"Average cut size is {average_cut_size}")
# QuantumUtil.histogram_of_classical_states(result)
show_graph_partition(nodes, edges, partition)
