# %% [markdown]
# # `quantumsim.py` vs `quantumsim_performante.py`
#
# The regular (Nico's) version of QuantumSim compared to the more performance (Wouter's) version of QuantumSim. This comparison does not focus on peformance, it is a check if the performance version of QuantumSim has the same output as the regular version. The regular version is the standard to which the performance version is compared to.
#
# The tests are copied from the `QuantumSimNoise.ipynb` notebook

# %% [markdown]
# # Regular QuantumSim

# %%
from quantumsim import *

# %% [markdown]
# ## Test 1

# %%
n = 100 # Number of gate operations
circuit = NoisyCircuit(1)
for i in range(n):
    circuit.pauli_x(0)
    circuit.add_noisy_operation_coherent_x(3, 0)
circuit.add_noisy_operation_state_prep(0.08, 0)
circuit.add_noisy_operation_incoherent(0.007, 0.008, 0.009, 0)
circuit.add_noisy_operation_readout(0.02, 0.05, 0)

result = QuantumUtil.measure_circuit(circuit, nr_measurements=1000)
QuantumUtil.histogram_of_classical_states(result)

# %% [markdown]
# ## Test 2

# %%
n = 100
circuit = NoisyCircuit(2)
for i in range(n):
    circuit.pauli_x(0)
    circuit.add_noisy_operation_coherent_x(3, 0)
    circuit.pauli_y(1)
    circuit.add_noisy_operation_coherent_x(4, 1)
circuit.add_noisy_operation_state_prep(0.08, 0)
circuit.add_noisy_operation_state_prep(0.07, 1)
circuit.add_noisy_operation_incoherent(0.007, 0.008, 0.009, 0)
circuit.add_noisy_operation_incoherent(0.003, 0.004, 0.005, 1)
circuit.add_noisy_operation_readout(0.02, 0.05, 0)
circuit.add_noisy_operation_readout(0.04, 0.03, 0)

result = QuantumUtil.measure_circuit(circuit, nr_measurements=1000)
QuantumUtil.histogram_of_classical_states(result)

# %% [markdown]
# ## Test 3

# %%
n = 100
circuit = NoisyCircuit(2)
for i in range(n):
    circuit.pauli_x(0)
    circuit.add_noisy_operation_coherent_x(3, 0)
    circuit.cnot(0,1)

result = QuantumUtil.measure_circuit(circuit, nr_measurements=1000)
QuantumUtil.histogram_of_classical_states(result)

# %% [markdown]
# # QuantumSim performante

# %%
from quantumsim_performante import *
from quantumsim_performante.quantumsim_performante import *
import quantumsim_performante.quantumutil as QuantumUtil

# %% [markdown]
# ## Test 1

# %%
n = 100 # Number of gate operations
circuit = NoisyCircuit(1)
for i in range(n):
    circuit.pauli_x(0)
    circuit.add_noisy_operation_coherent_x(3, 0)
circuit.add_noisy_operation_state_prep(0.08, 0)
circuit.add_noisy_operation_incoherent(0.007, 0.008, 0.009, 0)
circuit.add_noisy_operation_readout(0.02, 0.05, 0)

result = QuantumUtil.measure_circuit(circuit, nr_measurements=1000)
QuantumUtil.histogram_of_classical_states(result)
# Out:
# False
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 4
#       2 circuit = NoisyCircuit(1)
#       3 for i in range(n):
# ----> 4     circuit.pauli_x(0)
#       5     circuit.add_noisy_operation_coherent_x(3, 0)
#       6 circuit.add_noisy_operation_state_prep(0.08, 0)
#
# File c:\Users\Wouter Pennings\Documents\master\quantumsim\quantumsim_performante\quantumsim_performante.py:445, in Circuit.pauli_x(self, q)
#     442 gate_as_string = '.' * q + 'X' + '.' * (self.N - q - 1)
#     443 self.gates.append(gate_as_string)
# --> 445 if self.__lazy_evaluation:
#     446     # print("[INFO] Pauli_x operation lazely added to circuit")
#     447     self.descriptions.append(description)
#     448     self.operations.append(
#     449         lambda: CircuitUnitaryOperation.get_combined_operation_for_pauli_x(q, self.N, gpu=self.__use_gpu)
#     450         )
#
# AttributeError: 'NoisyCircuit' object has no attribute '_Circuit__lazy_evaluation'

# %% [markdown]
# ## Test 2

# %%
n = 100 # Number of gate operations
circuit = NoisyCircuit(2)
for i in range(n):
    circuit.pauli_x(0)
    circuit.add_noisy_operation_coherent_x(3, 0)
    circuit.pauli_y(1)
    circuit.add_noisy_operation_coherent_x(4, 1)
circuit.add_noisy_operation_state_prep(0.08, 0)
circuit.add_noisy_operation_state_prep(0.07, 1)
circuit.add_noisy_operation_incoherent(0.007, 0.008, 0.009, 0)
circuit.add_noisy_operation_incoherent(0.003, 0.004, 0.005, 1)
circuit.add_noisy_operation_readout(0.02, 0.05, 0)
circuit.add_noisy_operation_readout(0.04, 0.03, 0)

result = QuantumUtil.measure_circuit(circuit, nr_measurements=1000)
QuantumUtil.histogram_of_classical_states(result)

# %% [markdown]
# ## Test 3

# %%
n = 100 # Number of gate operations
circuit = NoisyCircuit(2)
for i in range(n):
    circuit.pauli_x(0)
    circuit.add_noisy_operation_coherent_x(3, 0)
    circuit.cnot(0,1)

result = QuantumUtil.measure_circuit(circuit, nr_measurements=1000)
QuantumUtil.histogram_of_classical_states(result)

# %% [markdown]
# ## Conclusion
#
# `quantumsim_performante.py` is identical `quantumsim.py` as all three test have the same output
